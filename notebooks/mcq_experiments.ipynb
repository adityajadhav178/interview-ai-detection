# %% [markdown]
# ## MCQ experiments
#
# Use this notebook to explore questionnaire preprocessing, feature engineering, and baseline tabular models.

# %%
from pathlib import Path

project_root = Path('..').resolve()
project_root
